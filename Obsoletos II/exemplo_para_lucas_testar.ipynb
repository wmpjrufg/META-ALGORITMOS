# %%
pip install -i https://test.pypi.org/simple/ META-TOOLBOX
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Collecting META-TOOLBOX
#   Downloading https://test-files.pythonhosted.org/packages/af/1b/6561223f7d71ad22eda69567fb6d4c0aeae14c91f5be7b591c0d94663936/META_TOOLBOX-0.0.0.tar.gz (16 kB)
# Building wheels for collected packages: META-TOOLBOX
#   Building wheel for META-TOOLBOX (setup.py) ... done
#   Created wheel for META-TOOLBOX: filename=META_TOOLBOX-0.0.0-py3-none-any.whl size=21710 sha256=dbea7250d6f3b6ade5ae6f0a638344935b87f224d123b382798bbb6c4ceb73c0
#   Stored in directory: /root/.cache/pip/wheels/09/7a/b0/0055841b3c5ccc0f56cf892d6e250c90db2253dbeacb8b1e4e
# Successfully built META-TOOLBOX
# Installing collected packages: META-TOOLBOX
# Successfully installed META-TOOLBOX-0.0.0

# %%
from META_TOOLBOX import *

N_REP = 4
N_ITER = 150
X_L = [-30] * 4
X_U = [30] * 4
D = 4
M = 2
GAMMA = GAMMA_ASSEMBLY(X_L, X_U, D, M)
SETUP_FA = {
         'N_REP': N_REP,
         'N_ITER': N_ITER,
         'N_POP': 10,
         'D': D,
         'X_L': X_L,
         'X_U': X_U,
         'BETA_0': 0.98,
         'ALPHA_MIN': 0.25,
         'ALPHA_MAX': 1.00,
         'THETA': 0.95,
         'GAMMA': GAMMA,
         'NULL_DIC': None
        }

# %%
# OBJ. Function
def OF_FUNCTION(X, NULL_DIC):
    # Função objetivo modelo
    OF = ROSENBROCK(X)
    return OF

# %%
[RESULTS_REP, BEST_REP, AVERAGE_REP, WORST_REP, STATUS] = FA_ALGORITHM_0001(OF_FUNCTION, SETUP_FA)
# Out:
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Process Time: 1.56 Seconds
#  Seconds per repetition: 0.39

# %%
BEST_REP_ID = STATUS[0]
BEST_REP_ID
# Out:
# 3

# %%
STATUS
# Out:
# array([3, 2, 0, 1])

# %%
BEST = BEST_REP[BEST_REP_ID]
AVERAGE = AVERAGE_REP[BEST_REP_ID]
WORST = WORST_REP[BEST_REP_ID]
PLOT_SETUP = {
              'NAME': 'WANDER-OF',
              'WIDTH': 0.40, 
              'HEIGHT': 0.20,
              'DPI': 600, 
              'EXTENSION': '.svg',
              'COLOR OF': '#000000',
              'MARKER OF': 's',
              'COLOR FIT': '#000000',
              'MARKER FIT': 's',
              'MARKER SIZE': 6,
              'LINE WIDTH': 4,
              'LINE STYLE': '--',
              'OF AXIS LABEL': '$W (kN) $',
              'X AXIS LABEL': 'Number of objective function evaluations',
              'LABELS SIZE': 14,
              'LABELS COLOR': '#000000',
              'X AXIS SIZE': 14,
              'Y AXIS SIZE': 14,
              'AXISES COLOR': '#000000',
              'ON GRID?': True,
              'Y LOG': True,
              'X LOG': False,
             }
DATASET = {'X': BEST['NEOF'], 'OF': BEST['OF'], 'FIT': BEST['FIT']}
META_PLOT_001(DATASET, PLOT_SETUP)

# %%
PLOT_SETUP = {
              'NAME': 'WANDER-OF',
              'WIDTH': 0.40, 
              'HEIGHT': 0.20,
              'DPI': 600, 
              'EXTENSION': '.svg',
              'COLOR': '#000000',
              'MARKER': 's',
              'MARKER SIZE': 6,
              'LINE WIDTH': 4,
              'LINE STYLE': '--',
              'Y AXIS LABEL': '$W (kN) $',
              'X AXIS LABEL': 'Number of objective function evaluations',
              'LABELS SIZE': 14,
              'LABELS COLOR': '#000000',
              'X AXIS SIZE': 14,
              'Y AXIS SIZE': 14,
              'AXISES COLOR': '#000000',
              'ON GRID?': True,
              'Y LOG': True,
              'X LOG': False,
             }
DATASET = {'X': BEST['NEOF'], 'Y': BEST['OF']}
META_PLOT_002(DATASET, PLOT_SETUP)

# %%
PLOT_SETUP = {
              'NAME': 'WANDER-OF',
              'WIDTH': 0.40, 
              'HEIGHT': 0.20,
              'DPI': 600, 
              'EXTENSION': '.svg',
              'COLOR BEST': '#00008B',
              'COLOR WORST': '#000000',
              'COLOR AVERAGE': '#ffcbdb',
              'MARKER': 's',
              'MARKER SIZE': 6,
              'LINE WIDTH': 4,
              'LINE STYLE': '--',
              'Y AXIS LABEL': '$W (kN) $',
              'X AXIS LABEL': 'Number of objective function evaluations',
              'LABELS SIZE': 14,
              'LABELS COLOR': '#000000',
              'X AXIS SIZE': 14,
              'Y AXIS SIZE': 14,
              'AXISES COLOR': '#000000',
              'ON GRID?': True,
              'LOC LEGEND': 'upper right',
              'SIZE LEGEND': 12,
              'Y LOG': True,
              'X LOG': False
             }
DATASET = {'X': BEST['NEOF'], 'BEST': BEST['OF'], 'AVERAGE': AVERAGE['OF'], 'WORST': WORST['OF']}
META_PLOT_003(DATASET, PLOT_SETUP)

# %%
PLOT_SETUP = {
              'NAME': 'WANDER-OF',
              'WIDTH': 0.40, 
              'HEIGHT': 0.20,
              'DPI': 600, 
              'EXTENSION': '.svg',
              'MARKER': 's',
              'X AXIS LABEL': 'OF values',
              'X AXIS SIZE': 14,
              'Y AXIS SIZE': 14,
              'LABELS SIZE': 14,
              'LABELS COLOR': '#000000',
              'COLOR': '#000000',
              'AXISES COLOR': '#000000',
              'BINS': 20,
              'KDE': False,
             }
DATASET = {'NUMBER OF REPETITIONS': N_REP, 'NUMBER OF ITERATIONS': N_ITER, 'OF OR FIT': 'OF', 'BEST': BEST_REP}
META_PLOT_004(DATASET, PLOT_SETUP)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
